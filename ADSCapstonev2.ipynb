# %%
import pandas as pd
import numpy as np
import folium

# %%
# Read CSV file
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# Remove irrelevant tables
df = df[0]

# Drop NA values
df = df.dropna()

# Change "Postal code" to "Postal Code"
df.rename(columns = {'Postal code': 'Postal Code'}, inplace = True)

# Import Coordinates CSV
geocoords = 'Geospatial_Coordinates.csv'

# Create data frame for Coordinates
df2 = pd.read_csv(geocoords)

# Merge Neighborhoods Data Frame and Coordinates Data Frame
df = df.merge(df2, how="outer", on = 'Postal Code')
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                           Regent Park / Harbourfront  43.654260 -79.360636
# 3                    Lawrence Manor / Lawrence Heights  43.718518 -79.464763
# 4         Queen's Park / Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# ...

# %%
# Create map
mooseWorldMap = folium.Map(location = [43.628841, -79.520999])

# Create postal code markers
for (index, row) in df.iterrows():
    folium.Marker(location = [row.loc['Latitude'], row.loc['Longitude']],
                 popup = row.loc['Postal Code']).add_to(mooseWorldMap)

mooseWorldMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
